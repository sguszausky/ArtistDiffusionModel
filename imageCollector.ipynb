# %%
import dataPreperation.imageDownloader as downloader
import importlib
import dataPreperation.datasetPreparation as prep

# %%
importlib.reload(downloader)
contact = "sguszausky@techfak.de"  #Contact info for user-agent
category = "Category:Paintings by Edgar Payne"  # Wikimedia category to download from
outputDirectory = "dataset/Edgar_Payne_all" # Output directory for downloaded images
api = "https://commons.wikimedia.org/w/api.php" # Wikimedia Commons API endpoint

licenseControl = True   # Whether to filter images by license
sleepTime = 0.2      # seconds to sleep between requests
batchSize = 50      # number of files to query for imageinfo in one request

# %%
session = downloader.make_session(contact)
# Connectivity test, should return site info
downloader.test_connection(session,api)

# %%
downloader.download_all_images(
    session,
    api,
    outputDirectory,
    category,
    licenseControl,
    sleepTime,
    batchSize
)
# Out:
# Fetching files from Category:Paintings by Edgar Payne ...
# Found 133 files in category.
# Fetching image URLs + license metadata ...
# Got imageinfo for 133 files.
#   downloaded 1 (last: File:Edgar Alwyn Payne 2.jpg)
#   downloaded 2 (last: File:Edgar Alwyn Payne Along the Riviera, Menton, France.jpg)
#   downloaded 3 (last: File:Edgar Alwyn Payne Alpine Lake.jpg)
#   downloaded 10 (last: File:Edgar Alwyn Payne Big Pine Lake Sierra Nevada Temple Crag.jpg)
#   downloaded 20 (last: File:Edgar Payne Clouds over Mount Whitney.jpg)
#   downloaded 30 (last: File:Edgar Payne Eucalyptus Landscape, California.jpg)
#   downloaded 40 (last: File:Edgar Payne High Sierras.jpg)
#   downloaded 50 (last: File:Edgar Payne Packing Out from Payne Lake.jpg)
#   downloaded 60 (last: File:Edgar Payne Riders on Horseback.jpg)
#   downloaded 70 (last: File:Edgar Payne Sierra Madre from Mt. Vista.jpg)
#   downloaded 80 (last: File:Edgar Payne Summer Cloud.jpg)
#   downloaded 90 (last: File:Edgar Payne The Eastern Sierra.jpg)
#   downloaded 100 (last: File:Edgar Payne View of the Glacier and Palisades, Rockies.jpg)
#   downloaded 110 (last: File:Late Afternoon, Pasadena.jpg)
#   downloaded 120 (last: File:Mountain Range at Sunset.jpg)
#   downloaded 130 (last: File:Sierra Lake, by Edgar Alwin Payne.jpg)
#
# === DONE ===
# Downloaded: 133
# Skipped (license): 0
# Skipped (already exists): 0
# Failed: 0
# Manifest: dataset/Edgar_Payne_all\manifest.json

# %%
#Smaller images as 512 are not suitable
imagesTooSmall = prep.filterBySize(outputDirectory, minWidth = 512, minHeight=512)
prep.deleteImages(imagesTooSmall)
# Out:
# Found 15 images smaller as 512×512
# Edgar Alwyn Payne Blue Canyon.jpg: 600×500
# Edgar Alwyn Payne California Landscape.jpg: 545×402
# Edgar Alwyn Payne Canyon de Chelly.jpg: 512×422
# Edgar Payne Clouds over Mount Whitney.jpg: 500×366
# Edgar Payne Edgar Payne display image.jpg: 500×404
# Edgar Payne Eucalyptus and Hills.jpg: 541×476
# Edgar Payne Forth Lake, Big Pine.jpg: 553×432
# Edgar Payne Hills of Altadena.png: 570×454
# Edgar Payne Riders on Horseback.jpg: 512×424
# Edgar Payne View of the Glacier and Palisades, Rockies.jpg: 510×405
# Lake in the High Sierras 2000 LAX 09404 0089 000(010613).jpg: 512×428
# Landscape in Switzerland.jpg: 500×409
# Late Afternoon, Pasadena.jpg: 520×384
# Narrows, Canyon de Chelly.jpg: 520×435
# Navajo Riders.jpg: 600×484

# %%
#Crop the bottom 5% to not include signature
croppedDir="dataset/Edgar_Payne_cropped"
prep.cropBottomPercent(
    imageDir=outputDirectory,
    outDir=croppedDir,
    cropPercent=5.0,
    overwrite=False
)
# Out:
# Cropped: Edgar Alwyn Payne 2.jpg (751×600 -> 751×570)
# Cropped: Edgar Alwyn Payne Alpine Lake.jpg (2000×1645 -> 2000×1563)
# Cropped: Edgar Alwyn Payne Altadena Dawn.jpg (1239×1024 -> 1239×973)
# Cropped: Edgar Payne High Sierra Lake.jpg (749×624 -> 749×593)
# Cropped: Edgar Payne Sierra Mountains.jpg (900×733 -> 900×697)
# Cropped: Land of the Navajo.jpg (1720×1440 -> 1720×1368)
#
# Result
# Processed: 93
# Skipped: 0
# Failed: 0
# Output: dataset\Edgar_Payne_cropped

# %%
#Filter again by images smaller than 512, if there are too many after cropping consider cropping less or by hand to be more precise
imagesTooSmall = prep.filterBySize(croppedDir, minWidth = 512, minHeight=512)
# Out:
# Found 3 images smaller as 512×512
# Edgar Alwyn Payne California Mountain, High Sierras.jpg: 650×498
# Edgar Payne Sierra Lake.jpg: 600×493
# Edgar Payne Snow-Covered Peaks.jpg: 640×510

# %%
prep.deleteImages(imagesTooSmall)
# Out:
# Deleted: Edgar Alwyn Payne California Mountain, High Sierras.jpg (650×498)
# Deleted: Edgar Payne Sierra Lake.jpg (600×493)
# Deleted: Edgar Payne Snow-Covered Peaks.jpg (640×510)
#
# Result
# Deleted: 3
# Skipped: 0

# %%
importlib.reload(prep)
outputRename = "dataset/Edgar_Payne_all_num"
prep.numberImagesandCreateDict(outputRename)
# Out:
# Renamed 90 images.
# Mapping saved to: C:\Users\gusza\Uni\VertiefungNeuronaleNetze\ArtsistDiffusionModel\dataset\Edgar_Payne_all_num\mapping.xlsx
# WindowsPath('C:/Users/gusza/Uni/VertiefungNeuronaleNetze/ArtsistDiffusionModel/dataset/Edgar_Payne_all_num/mapping.xlsx')
